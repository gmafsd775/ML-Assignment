# %%
import numpy as np
import pandas as pd
import os
from sklearn import linear_model

# %%
df = pd.read_csv('/content/drive/MyDrive/ML Assignment 2/Concrete_Data_Yeh.csv')
df
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 2      332.5  142.5     0.0  228.0               0.0            932.0
# 3      332.5  142.5     0.0  228.0               0.0            932.0
# 4      198.6  132.4     0.0  192.0               0.0            978.4
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age  csMPa
# 0             676.0   28  79.99
# 1             676.0   28  61.89
# ...

# %%
lr = linear_model.LinearRegression()
lr.fit(df[['cement','slag','flyash','water','superplasticizer','coarseaggregate','fineaggregate','age']],df.csMPa)
# Out:
# LinearRegression()

# %%
lr.predict([[450,80,50,180,1.8,1020,680,56]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([55.40122023])

# %%
lr.coef_
# Out:
# array([ 0.11980433,  0.10386581,  0.08793432, -0.14991842,  0.2922246 ,
#         0.01808621,  0.02019035,  0.11422207])

# %%
lr.intercept_
# Out:
# np.float64(-23.331213584903225)

# %%
# y = m1x1 + m2x2 + m3x3 + m4x4 + m5x5 + m6x6 + m7x7 + m8x8 + m9x9 + b0        Formula

predict = 0.11980433*450 + 0.10386581*80 + 0.08793432*50 +  -0.14991842*180 + 0.2922246*1.8 + 0.01808621*1020 + 0.02019035*680 + 0.11422207*56 + -23.331213584903225
print(predict)
# Out:
# 55.40121251509677
